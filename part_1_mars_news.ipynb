# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup as soup

# %%
browser = Browser('chrome')

# %%
# Visit the Mars news site
url = 'https://static.bc-edx.com/data/web/mars_news/index.html'
browser.visit(url)

# %%
# Create a Beautiful Soup object
html = browser.html
news_soup = soup(html, 'html.parser')

# %%
# Extract all text elements
all_text = news_soup.get_text()
print(all_text)
# Out:
# News - Mars Exploration Program
#
#
#
#
#
#
#
# MARS Planet Science
# Exploration Program
#
#
#
#
#
#
#
# The Red Planet
#
#
# The Program
#
#
# News & Events
#
#
# Multimedia
#
#
# Missions
#
#
# More
#
#
#
#
#
#
#
#
#
#
# News
#
#
#
#
#
#
#
#
# Latest
#
#
#
#
# All Categories
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# November 9, 2022
# NASA's MAVEN Observes Martian Light Show Caused by Major Solar Storm
# For the first time in its eight years orbiting Mars, NASA’s MAVEN mission witnessed two different types of ultraviolet aurorae simultaneously, the result of solar storms that began on Aug. 27.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# November 1, 2022
# NASA Prepares to Say 'Farewell' to InSight Spacecraft
# A closer look at what goes into wrapping up the mission as the spacecraft’s power supply continues to dwindle.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# October 28, 2022
# NASA and ESA Agree on Next Steps to Return Mars Samples to Earth
# ...

# %%
# Create an empty list to store the dictionaries
news_list = []

# Iterate over each article
for article in nsoup.find_all('div', class_='list_text'):
    # Get the title text
    title = article.find('div', class_='content_title').text
    
    # Get the preview text
    preview = article.find('div', class_='article_teaser_body').text
    
    # Create a dictionary with the title and preview text
    news_dict = {'title': title, 'preview': preview}
    
    # Append the dictionary to the list
    news_list.append(news_dict)

# Print the list
print(news_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_132\2622130756.py in <module>
#       3
#       4 # Iterate over each article
# ----> 5 for article in soup.find_all('div', class_='list_text'):
#       6     # Get the title text
#       7     title = article.find('div', class_='content_title').text
#
# ~\anaconda\Anaconda3\lib\site-packages\bs4\element.py in find_all(self, name, attrs, recursive, string, limit, **kwargs)
#    1887         :rtype: bs4.element.ResultSet
#    1888         """
# -> 1889         generator = self.descendants
#    1890         if not recursive:
#    1891             generator = self.children
#
# AttributeError: 'str' object has no attribute 'descendants'

# %%
# Create a BeautifulSoup object
BeautifulSoup = soup(url, 'html.parser')

# Loop through the text elements
news_list = []
for element in soup.find_all('div', class_='list_text'):
    # Extract the title and preview text from the elements
    title = element.find('div', class_='content_title').text
    preview = element.find('div', class_='article_teaser_body').text
    
    # Create a dictionary with the title and preview text
    news_dict = {'title': title, 'preview': preview}
    
    # Add the dictionary to the list
    news_list.append(news_dict)

# %%
# Print the list to confirm success

for news in news_list:
    print(news)

# %%
browser.quit()
